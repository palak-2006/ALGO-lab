# %% [markdown]
# <a href="https://colab.research.google.com/github/palak-2006/ALGO-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    visited = []

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}
    neighbors = int(input(f"Enter number of neighbors for {node}: "))
    for j in range(neighbors):
        neighbor = input("Enter neighbor name: ")
        weight = int(input(f"Enter weight from {node} to {neighbor}: "))
        graph[node][neighbor] = weight

start = input("Enter starting node: ")
result = dijkstra(graph, start)

for node in result:
    print("Distance from", start, "to", node, "=", result[node])
# Out:
# Enter number of nodes: 4
# Enter node 1 name: 1
# Enter number of neighbors for 1: 2
# Enter neighbor name: 4
# Enter weight from 1 to 4: 2
# Enter neighbor name: 5
# Enter weight from 1 to 5: 2
# Enter node 2 name: 2
# Enter number of neighbors for 2: 1
# Enter neighbor name: 3
# Enter weight from 2 to 3: 3
# Enter node 3 name: 4
# Enter number of neighbors for 4: 2
# Enter neighbor name: 5
# Enter weight from 4 to 5: 2
# Enter neighbor name: 6
# Enter weight from 4 to 6: 2
# Enter node 4 name: 5
# Enter number of neighbors for 5: 2
# Enter neighbor name: 7
# Enter weight from 5 to 7: 2
# Enter neighbor name: 8
# Enter weight from 5 to 8: 2
# Enter starting node: 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12497/559816461.py in <cell line: 0>()
#      33
#      34 start = input("Enter starting node: ")
# ---> 35 result = dijkstra(graph, start)
#      36
#      37 for node in result:
#
# /tmp/ipykernel_12497/559816461.py in dijkstra(graph, start)
#      17         for neighbor, weight in graph[min_node].items():
#      18             new_distance = distances[min_node] + weight
# ---> 19             if new_distance < distances[neighbor]:
#      20                 distances[neighbor] = new_distance
#      21
#
# KeyError: '6'

# %%
def dijkstra_with_path(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    visited = []
    predecessors = {node: None for node in graph}

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

def print_path(predecessors, start, end):
    path = []
    current = end
    while current is not None:
        path.insert(0, current)
        current = predecessors[current]
    print("Shortest path from", start, "to", end, ":", " -> ".join(path))

# Example graph
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3}
}

distances, predecessors = dijkstra_with_path(graph, 'A')
for node in distances:
    print("Distance from A to", node, "=", distances[node])
    print_path(predecessors, 'A', node)

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 4},
    'D': {'B': 10, 'C': 3, 'F': 11},
    'E': {'C': 4, 'F': 6},
    'F': {'D': 11, 'E': 6}
}

distances, predecessors = dijkstra_with_path(graph, 'A')
for node in distances:
    print("Distance from A to", node, "=", distances[node])
    print_path(predecessors, 'A', node)

# %%
sources = ['A', 'C', 'E']  # try different starting points

for start in sources:
    print("\n--- Starting from", start, "---")
    distances, predecessors = dijkstra_with_path(graph, start)
    for node in distances:
        print("Distance from", start, "to", node, "=", distances[node])
        print_path(predecessors, start, node)
